# %%
import pandas as pd

# Specify the full path to your CSV file
file_path = r"C:\Users\bhavy\Downloads\NewspaperData.csv"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to confirm the data
print(df.head())
# Out:
#             Newspaper    daily   sunday
# 0       Baltimore Sun  391.952  488.506
# 1        Boston Globe  516.981  798.298
# 2       Boston Herald  355.628  235.084
# 3  Charlotte Observer  238.555  299.451
# 4   Chicago Sun Times  537.780  559.093

# %%
df.shape #to get no. of rows and columns
# Out:
# (34, 3)

# %%
#we can find correlation if there are numerical values, now we should filter numerical values features into a new dataframes
df_new=df.select_dtypes(include=['float64', 'int64'])
print(df_new)
# Out:
#        daily    sunday
# 0    391.952   488.506
# 1    516.981   798.298
# 2    355.628   235.084
# 3    238.555   299.451
# 4    537.780   559.093
# 5    733.775  1133.249
# 6    198.832   348.744
# 7    252.624   417.779
# 8    206.204   344.522
# 9    231.177   323.084
# 10   449.755   620.752
# 11   288.571   423.305
# 12   185.736   202.614
# 13  1164.388  1531.527
# 14   444.581   553.479
# 15   412.871   685.975
# 16   272.280   324.241
# 17   781.796   983.240
# 18  1209.225  1762.015
# 19   825.512   960.308
# 20   223.748   284.611
# 21   354.843   407.760
# 22   515.523   982.663
# 23   220.465   557.000
# 24   337.672   440.923
# 25   197.120   268.060
# 26   133.239   262.048
# 27   374.009   432.502
# 28   273.844   338.355
# 29   570.364   704.322
# 30   391.286   585.681
# 31   201.860   267.781
# 32   321.626   408.343
# 33   838.902  1165.567

# %%
df_new.corr() #to find correlation between them
# Out:
#            daily    sunday
# daily   1.000000  0.958154
# sunday  0.958154  1.000000

# %%
#finding histogram
import seaborn as sns
sns.histplot(df['daily'])
# Out:
# <Axes: xlabel='daily', ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(df['sunday'])
# Out:
# <Axes: xlabel='sunday', ylabel='Count'>

# %%
#scatterplot
#fitting a linear regression model
import statsmodels.formula.api as smf
model=smf.ols("sunday~daily",data=df).fit()

# %%
sns.regplot(x="daily",y="sunday",data=df);

# %%
#t and p values
#r square value
