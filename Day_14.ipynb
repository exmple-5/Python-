# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
claim_data=pd.read_csv()
claim_data
# Out:
# <function pandas.io.parsers.readers.read_csv(filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]', *, sep: 'str | None | lib.NoDefault' = <no_default>, delimiter: 'str | None | lib.NoDefault' = None, header: "int | Sequence[int] | None | Literal['infer']" = 'infer', names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>, index_col: 'IndexLabel | Literal[False] | None' = None, usecols=None, dtype: 'DtypeArg | None' = None, engine: 'CSVEngine | None' = None, converters=None, true_values=None, false_values=None, skipinitialspace: 'bool' = False, skiprows=None, skipfooter: 'int' = 0, nrows: 'int | None' = None, na_values=None, keep_default_na: 'bool' = True, na_filter: 'bool' = True, verbose: 'bool' = False, skip_blank_lines: 'bool' = True, parse_dates: 'bool | Sequence[Hashable] | None' = None, infer_datetime_format: 'bool | lib.NoDefault' = <no_default>, keep_date_col: 'bool' = False, date_parser=<no_default>, date_format: 'str | None' = None, dayfirst:
# ...

# %%
df=sns.load_dataset('taxis')

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.barplot(x='color',y='total',data=df)
plt.show()

# %%
sns.barplot(x='color',y='total',data=df,color='red')
plt.show()

# %%
sns.barplot(x='color',y='total',data=df,color='red',estimator='max')
plt.show()

# %%
sns.barplot(x='color',y='total',data=df,color='red',estimator='min')
plt.show()

# %%
sns.barplot(x='color',y='total',data=df,color='red',estimator='sum')
plt.show()

# %%
sns.barplot(x='color',y='total',data=df,color='red',estimator='max')
plt.show()
plt.tight_layout()

# %%
sns.histplot(x=df['fare'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x=df['fare'],color='green')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x=df['fare'],color='red',hue=df['color'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x=df['fare'],color='pink',hue=df['payment'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(x=df['fare'],palette=['red','pink'],hue=df['payment'])
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.violinplot(x=df['fare'])
# Out:
# <Axes: xlabel='fare'>

# %%
sns.violinplot(x=df['fare'],y=df['payment'])
# Out:
# <Axes: xlabel='fare', ylabel='payment'>

# %%
sns.violinplot(x=df['fare'],y=df['payment'],palette=['green','y'])
# Out:
# <Axes: xlabel='fare', ylabel='payment'>

# %%
sns.boxplot(x=df['fare'])
# Out:
# <Axes: xlabel='fare'>

# %%
sns.boxplot(x=df['fare'],y=df['payment'],palette=['green','red'])
# Out:
# <Axes: xlabel='fare', ylabel='payment'>

# %%
sns.scatterplot(x=df['fare'],y=df['total'],palette=['green','red'],hue=df['payment'])
# Out:
# <Axes: xlabel='fare', ylabel='total'>

# %%
sns.stripplot(x=df['color'],y=df['fare'],palette=['green','blue'])
# Out:
# <Axes: xlabel='color', ylabel='fare'>
